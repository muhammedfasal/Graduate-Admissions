# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import random
from sklearn import metrics

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col2 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col3 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col4 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col5 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col6 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col7 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row1_col8 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col1 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col3 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col4 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col5 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col6 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col7 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row2_col8 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col1 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col2 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col4 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col5 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col6 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col7 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row3_col8 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col1 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col2 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col3 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col5 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col6 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col7 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row4_col8 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col1 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col2 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col3 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col4 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col6 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col7 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row5_col8 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row6_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row6_col1 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row6_col2 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row6_col3 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row6_col4 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_6cf19600_7918_11eb_805b_c0143dd6bc25row6_col5 {
#             background-color:  #f7ad90;
#             color:  #000000;

# %%
X = df[['CGPA','GRE Score','TOEFL Score','Research','University Rating']]
Y = df[['Chance of Admit ']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=0,test_size=0.2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = reg.predict(X_test)

# %%
mse=metrics.mean_squared_error(Y_test,pred)
mse
# Out:
# 0.005115926455561133

# %%
X_test
# Out:
#      CGPA  GRE Score  TOEFL Score  Research  University Rating
# 132  8.56        309          105         0                  5
# 309  8.60        308          110         0                  4
# 341  8.76        326          110         1                  3
# 196  8.26        306          105         0                  2
# 246  8.73        316          105         0                  3
# ..    ...        ...          ...       ...                ...
# 14   8.20        311          104         1                  3
# 363  8.36        306          103         0                  2
# 304  8.43        313          106         0                  2
# 361  9.54        334          116         1                  4
# 329  7.89        297           96         0                  2
#
# [80 rows x 5 columns]

# %%
Y_test
# Out:
#      Chance of Admit
# 132              0.71
# 309              0.70
# 341              0.79
# 196              0.73
# 246              0.72
# ..                ...
# 14               0.61
# 363              0.69
# 304              0.62
# 361              0.93
# 329              0.43
#
# [80 rows x 1 columns]

# %%
user_input = [[8.56,309,105,0,5]] #user input from testing data
user_pred = reg.predict(user_input)
print(user_pred)
# Out:
# [[0.70623199]]

# %%
user_input = [[9.54,334,116,1,4]] #user input from testing data
user_pred = reg.predict(user_input)
print((user_pred.flatten()*100).astype(float))
# Out:
# [92.27656667]

# %%
import pickle

# %%
pickle.dump(reg,open('new_model.pkl','wb'))
